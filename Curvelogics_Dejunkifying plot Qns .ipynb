# %% [markdown]
# Here's some sample code which has the ticks, can you figure out how to remove them?<br>
# Task 1: Remove all the ticks (both axes), and tick labels on the Y axis<br>
# Task 2: Remove frame of the chart<br>
# Task 3: Change the bar colors to be less bright blue, make one bar, the python bar, a contrasting color,soften all labels by turning grey.<br>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()


languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)
#Task1: Remove all the ticks (both axes), and tick labels on the Y axis
#Please provide your answer below this line




#Task2: Remove frame of the chart
#Please provide your answer below this line





#Task3:Change the bar colors to be less bright blue, make one bar, the python bar,
# a contrasting color,soften all labels by turning grey.
#Please provide your answer below this line 





plt.show()
